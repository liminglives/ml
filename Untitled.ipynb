# %%
import pandas as pd
import numpy as np

# %%
data_train = pd.read_csv('train.csv')
data_train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
data_train.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
data_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
data_train.describle()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-4130c39568dc> in <module>()
# ----> 1 data_train.describle()
#
# C:\Users\zlm\Anaconda2\lib\site-packages\pandas\core\generic.pyc in __getattr__(self, name)
#    2968             if name in self._info_axis:
#    2969                 return self[name]
# -> 2970             return object.__getattribute__(self, name)
#    2971
#    2972     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'describle'

# %%
data_train_describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-9a4f078ef633> in <module>()
# ----> 1 data_train_describe()
#
# NameError: name 'data_train_describe' is not defined

# %%
data_train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
fig = plt.figure(figsize=fizsize_with_subplots)
fig_dims = (3, 2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-13907ff5a600> in <module>()
# ----> 1 fig = plt.figure(figsize=fizsize_with_subplots)
#       2 fig_dims = (3, 2)
#
# NameError: name 'plt' is not defined

# %%
import pylab as plt
fig = plt.figure(figsize=fizsize_with_subplots)
fig_dims = (3, 2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-9e58c0afef3d> in <module>()
#       1 import pylab as plt
# ----> 2 fig = plt.figure(figsize=fizsize_with_subplots)
#       3 fig_dims = (3, 2)
#
# NameError: name 'fizsize_with_subplots' is not defined

# %%
import pylab as plt
# Set the global default size of matplotlib figures
plt.rc('figure', figsize=(10, 5))
# Size of matplotlib figures that contain subplots
fizsize_with_subplots = (10, 10)
# Size of matplotlib histogram bins
bin_size = 10
fig = plt.figure(figsize=fizsize_with_subplots)
fig_dims = (3, 2)

# %%
plt.subplot2grid(fig_dims, (0, 0))
survived_count = df_train['Survived'].value_counts()
print type(survived_count)
survived_count.plot(kind="bar", title="survived counts")

# Plot Pclass counts
plt.subplot2grid(fig_dims, (0, 1))
df_train['Pclass'].value_counts().plot(kind='bar', 
                                       title='Passenger Class Counts')

# Plot Sex counts
plt.subplot2grid(fig_dims, (1, 0))
df_train['Sex'].value_counts().plot(kind='bar', 
                                    title='Gender Counts')
plt.xticks(rotation=0)

# Plot Embarked counts
plt.subplot2grid(fig_dims, (1, 1))
df_train['Embarked'].value_counts().plot(kind='bar', 
                                         title='Ports of Embarkation Counts')

# Plot the Age histogram
plt.subplot2grid(fig_dims, (2, 0))
df_train['Age'].hist()
plt.title('Age Histogram')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-fb82c36bab8b> in <module>()
#       1 plt.subplot2grid(fig_dims, (0, 0))
# ----> 2 survived_count = df_train['Survived'].value_counts()
#       3 print type(survived_count)
#       4 survived_count.plot(kind="bar", title="survived counts")
#       5
#
# NameError: name 'df_train' is not defined

# %%
df_train = data_train
plt.subplot2grid(fig_dims, (0, 0))
survived_count = df_train['Survived'].value_counts()
print type(survived_count)
survived_count.plot(kind="bar", title="survived counts")

# Plot Pclass counts
plt.subplot2grid(fig_dims, (0, 1))
df_train['Pclass'].value_counts().plot(kind='bar', 
                                       title='Passenger Class Counts')

# Plot Sex counts
plt.subplot2grid(fig_dims, (1, 0))
df_train['Sex'].value_counts().plot(kind='bar', 
                                    title='Gender Counts')
plt.xticks(rotation=0)

# Plot Embarked counts
plt.subplot2grid(fig_dims, (1, 1))
df_train['Embarked'].value_counts().plot(kind='bar', 
                                         title='Ports of Embarkation Counts')

# Plot the Age histogram
plt.subplot2grid(fig_dims, (2, 0))
df_train['Age'].hist()
plt.title('Age Histogram')
# Out:
# <class 'pandas.core.series.Series'>

# %%
df_train = data_train
plt.subplot2grid(fig_dims, (0, 0))
survived_count = data_train['Survived'].value_counts()
print type(survived_count)
survived_count.plot(kind="bar", title="survived counts")

# Plot Pclass counts
plt.subplot2grid(fig_dims, (0, 1))
data_train['Pclass'].value_counts().plot(kind='bar', 
                                       title='Passenger Class Counts')

# Plot Sex counts
plt.subplot2grid(fig_dims, (1, 0))
data_train['Sex'].value_counts().plot(kind='bar', 
                                    title='Gender Counts')
plt.xticks(rotation=0)

# Plot Embarked counts
plt.subplot2grid(fig_dims, (1, 1))
data_train['Embarked'].value_counts().plot(kind='bar', 
                                         title='Ports of Embarkation Counts')

# Plot the Age histogram
plt.subplot2grid(fig_dims, (2, 0))
data_train['Age'].hist()
plt.title('Age Histogram')
# Out:
# <class 'pandas.core.series.Series'>

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
fig.set(alpha=0.2)  # 设定图表颜色alpha参数

plt.subplot2grid((2,3),(0,0))             # 在一张大图里分列几个小图
data_train.Survived.value_counts().plot(kind='bar')# 柱状图 
plt.title(u"获救情况 (1为获救)") # 标题
plt.ylabel(u"人数")  

plt.subplot2grid((2,3),(0,1))
data_train.Pclass.value_counts().plot(kind="bar")
plt.ylabel(u"人数")
plt.title(u"乘客等级分布")

plt.subplot2grid((2,3),(0,2))
plt.scatter(data_train.Survived, data_train.Age)
plt.ylabel(u"年龄")                         # 设定纵坐标名称
plt.grid(b=True, which='major', axis='y') 
plt.title(u"按年龄看获救分布 (1为获救)")


plt.subplot2grid((2,3),(1,0), colspan=2)
data_train.Age[data_train.Pclass == 1].plot(kind='kde')   
data_train.Age[data_train.Pclass == 2].plot(kind='kde')
data_train.Age[data_train.Pclass == 3].plot(kind='kde')
plt.xlabel(u"年龄")# plots an axis lable
plt.ylabel(u"密度") 
plt.title(u"各等级的乘客年龄分布")
plt.legend((u'头等舱', u'2等舱',u'3等舱'),loc='best') # sets our legend for our graph.


plt.subplot2grid((2,3),(1,2))
data_train.Embarked.value_counts().plot(kind='bar')
plt.title(u"各登船口岸上船人数")
plt.ylabel(u"人数")  
plt.show()

# %%
df_train = data_train
plt.subplot2grid(fig_dims, (0, 0))
survived_count = data_train['Survived'].value_counts()
print type(survived_count)
survived_count.plot(kind="bar", title="survived counts")

# Plot Pclass counts
plt.subplot2grid(fig_dims, (0, 1))
data_train['Pclass'].value_counts().plot(kind='bar', 
                                       title='Passenger Class Counts')

# Plot Sex counts
plt.subplot2grid(fig_dims, (1, 0))
data_train['Sex'].value_counts().plot(kind='bar', 
                                    title='Gender Counts')
plt.xticks(rotation=0)

# Plot Embarked counts
plt.subplot2grid(fig_dims, (1, 1))
data_train['Embarked'].value_counts().plot(kind='bar', 
                                         title='Ports of Embarkation Counts')

# Plot the Age histogram
plt.subplot2grid(fig_dims, (2, 0))
data_train['Age'].hist()
plt.title('Age Histogram')

plt.show()
# Out:
# <class 'pandas.core.series.Series'>

# %%
# Set the global default size of matplotlib figures
plt.rc('figure', figsize=(10, 5))
# Size of matplotlib figures that contain subplots
fizsize_with_subplots = (10, 10)
# Size of matplotlib histogram bins
bin_size = 10
fig = plt.figure(figsize=fizsize_with_subplots)
fig_dims = (3, 2)

df_train = data_train
plt.subplot2grid(fig_dims, (0, 0))
survived_count = data_train['Survived'].value_counts()
print type(survived_count)
survived_count.plot(kind="bar", title="survived counts")

# Plot Pclass counts
plt.subplot2grid(fig_dims, (0, 1))
data_train['Pclass'].value_counts().plot(kind='bar', 
                                       title='Passenger Class Counts')

# Plot Sex counts
plt.subplot2grid(fig_dims, (1, 0))
data_train['Sex'].value_counts().plot(kind='bar', 
                                    title='Gender Counts')
plt.xticks(rotation=0)

# Plot Embarked counts
plt.subplot2grid(fig_dims, (1, 1))
data_train['Embarked'].value_counts().plot(kind='bar', 
                                         title='Ports of Embarkation Counts')

# Plot the Age histogram
plt.subplot2grid(fig_dims, (2, 0))
data_train['Age'].hist()
plt.title('Age Histogram')

plt.show()
# Out:
# <class 'pandas.core.series.Series'>

# %%
pclass_sur = data_train.crosstab(data_train("PClass"), data_train("Survived"))
pclass_sur
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-1661d4ca162c> in <module>()
# ----> 1 pclass_sur = data_train.crosstab(data_train("PClass"), data_train("Survived"))
#       2 pclass_sur
#
# C:\Users\zlm\Anaconda2\lib\site-packages\pandas\core\generic.pyc in __getattr__(self, name)
#    2968             if name in self._info_axis:
#    2969                 return self[name]
# -> 2970             return object.__getattribute__(self, name)
#    2971
#    2972     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'crosstab'

# %%
pclass_sur = data_train.crosstab(data_train["PClass"], data_train["Survived"])
pclass_sur
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-64366e505428> in <module>()
# ----> 1 pclass_sur = data_train.crosstab(data_train["PClass"], data_train["Survived"])
#       2 pclass_sur
#
# C:\Users\zlm\Anaconda2\lib\site-packages\pandas\core\generic.pyc in __getattr__(self, name)
#    2968             if name in self._info_axis:
#    2969                 return self[name]
# -> 2970             return object.__getattribute__(self, name)
#    2971
#    2972     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'crosstab'

# %%
pclass_sur = pd.crosstab(data_train["PClass"], data_train["Survived"])
pclass_sur
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-5f2085427522> in <module>()
# ----> 1 pclass_sur = pd.crosstab(data_train["PClass"], data_train["Survived"])
#       2 pclass_sur
#
# C:\Users\zlm\Anaconda2\lib\site-packages\pandas\core\frame.pyc in __getitem__(self, key)
#    2060             return self._getitem_multilevel(key)
#    2061         else:
# -> 2062             return self._getitem_column(key)
#    2063
#    2064     def _getitem_column(self, key):
#
# C:\Users\zlm\Anaconda2\lib\site-packages\pandas\core\frame.pyc in _getitem_column(self, key)
#    2067         # get column
#    2068         if self.columns.is_unique:
# -> 2069             return self._get_item_cache(key)
#    2070
#    2071         # duplicate columns & possible reduce dimensionality
#
# ...

# %%
pclass_sur = pd.crosstab(data_train["Pclass"], data_train["Survived"])
pclass_sur
# Out:
# Survived    0    1
# Pclass
# 1          80  136
# 2          97   87
# 3         372  119

# %%
pclass_sur_pic = pclass_sur.div(pclass_sur.sum(1).astype(float), axis=0)
pclass_sur_pic.plot(kind="bar", stacked=True, title="Pclass Survived rate")
pclass_sur_pic.xlabel("pclass")
pclass_sur_pic.ylabel("survived rate")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-922152ce0a61> in <module>()
#       1 pclass_sur_pic = pclass_sur.div(pclass_sur.sum(1).astype(float), axis=0)
#       2 pclass_sur_pic.plot(kind="bar", stacked=True, title="Pclass Survived rate")
# ----> 3 pclass_sur_pic.xlabel("pclass")
#       4 pclass_sur_pic.ylabel("survived rate")
#       5 plt.show()
#
# C:\Users\zlm\Anaconda2\lib\site-packages\pandas\core\generic.pyc in __getattr__(self, name)
#    2968             if name in self._info_axis:
#    2969                 return self[name]
# -> 2970             return object.__getattribute__(self, name)
#    2971
#    2972     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'xlabel'

# %%
plt.xlabel("pclass")
plt.ylabel("survived rate")
plt.show()

# %%
print pclass_sur_pic
# Out:
# Survived         0         1
# Pclass
# 1         0.370370  0.629630
# 2         0.527174  0.472826
# 3         0.757637  0.242363

# %%
sex_uniq = data_train["Sex"].unique()
print sex_uniq
# Out:
# ['male' 'female']

# %%
print type(sex_uniq)
# Out:
# <type 'numpy.ndarray'>

# %%
print len(sex_uniq)
# Out:
# 2

# %%
sexes = sorted(sex_uniq)
gender_map = dict(zip(sexex, range(0, len(sexes) + 1)))
gender_map
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-26fc0d52b3ca> in <module>()
#       1 sexes = sorted(sex_uniq)
# ----> 2 gender_map = dict(zip(sexex, range(0, len(sexes) + 1)))
#       3 gender_map
#
# NameError: name 'sexex' is not defined

# %%
gender_map = dict(zip(sexes, range(0, len(sexes) + 1)))
gender_map
# Out:
# {'female': 0, 'male': 1}

# %%
print range(0, len(sexes) + 1)
# Out:
# [0, 1, 2]

# %%
data_train["Sev_Val"] = data_train["Sex"].map(gender_map).astype(int)
data_train.head
# Out:
# <bound method DataFrame.head of      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
data_train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
sex_pic = pd.crosstab(data_train["Sex_Val"], data_train["Survived"])
print sex_pic.sum(1)
print sex_pic.sum(0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-32-cf4746dbcd47> in <module>()
# ----> 1 sex_pic = pd.crosstab(data_train["Sex_Val"], data_train["Survived"])
#       2 print sex_pic.sum(1)
#       3 print sex_pic.sum(0)
#
# C:\Users\zlm\Anaconda2\lib\site-packages\pandas\core\frame.pyc in __getitem__(self, key)
#    2060             return self._getitem_multilevel(key)
#    2061         else:
# -> 2062             return self._getitem_column(key)
#    2063
#    2064     def _getitem_column(self, key):
#
# C:\Users\zlm\Anaconda2\lib\site-packages\pandas\core\frame.pyc in _getitem_column(self, key)
#    2067         # get column
#    2068         if self.columns.is_unique:
# -> 2069             return self._get_item_cache(key)
#    2070
#    2071         # duplicate columns & possible reduce dimensionality
#
# ...

# %%
sex_pic = pd.crosstab(data_train["Sev_Val"], data_train["Survived"])
print sex_pic.sum(1)
print sex_pic.sum(0)
# Out:
# Sev_Val
# 0    314
# 1    577
# dtype: int64
# Survived
# 0    549
# 1    342
# dtype: int64

# %%
print sex_pic.sum(1)
# Out:
# Sev_Val
# 0    314
# 1    577
# dtype: int64

# %%
sex_pic_show = sex_pic.div(sex_pic.sum(1).astype(float), axis=0)
sex_pic_show
# Out:
# Survived         0         1
# Sev_Val
# 0         0.257962  0.742038
# 1         0.811092  0.188908

# %%
sex_pic
# Out:
# Survived    0    1
# Sev_Val
# 0          81  233
# 1         468  109

# %%
sex_pic_show.plot(kind="bar", stacked=True, title="Sex Survived rate")
plt.xlabel("Sev_Val")
plt.ylabel("Survived")
plt.show()

# %%
female_df = data_train[data_train["Sex"] == "female"]
female_ct = pd.crosstab(female_df["Pclass"], female_df["survived"])
female_show = female_ct.div(female_ct.sum(1).astype(float), axis=0)
female_show.plot(kind="bar", stacked=True, title("pclass survived rate in female"))
plt.xlabel("pclass")
plt.ylabel("survived rate")
plt.show()
# Out:
#   File "<ipython-input-38-f401a088c7b6>", line 4
#     female_show.plot(kind="bar", stacked=True, title("pclass survived rate in female"))
# SyntaxError: non-keyword arg after keyword arg

# %%
female_show.plot(kind="bar", stacked=True, title = ("pclass survived rate in female"))
plt.xlabel("pclass")
plt.ylabel("survived rate")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-e4a296f94e11> in <module>()
# ----> 1 female_show.plot(kind="bar", stacked=True, title = ("pclass survived rate in female"))
#       2 plt.xlabel("pclass")
#       3 plt.ylabel("survived rate")
#       4 plt.show()
#
# NameError: name 'female_show' is not defined

# %%
female_df = data_train[data_train["Sex"] == "female"]
female_ct = pd.crosstab(female_df["Pclass"], female_df["survived"])
female_show = female_ct.div(female_ct.sum(1).astype(float), axis=0)
female_show.plot(kind="bar", stacked=True, title("pclass survived rate in female"))
plt.xlabel("pclass")
plt.ylabel("survived rate")
plt.show()
# Out:
#   File "<ipython-input-40-f401a088c7b6>", line 4
#     female_show.plot(kind="bar", stacked=True, title("pclass survived rate in female"))
# SyntaxError: non-keyword arg after keyword arg

# %%
female_df = data_train[data_train["Sex"] == "female"]
female_ct = pd.crosstab(female_df["Pclass"], female_df["survived"])
female_show = female_ct.div(female_ct.sum(1).astype(float), axis=0)
female_show.plot(kind="bar", stacked=True, title="pclass survived rate in female")
plt.xlabel("pclass")
plt.ylabel("survived rate")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-41-2c5caeb8b87f> in <module>()
#       1 female_df = data_train[data_train["Sex"] == "female"]
# ----> 2 female_ct = pd.crosstab(female_df["Pclass"], female_df["survived"])
#       3 female_show = female_ct.div(female_ct.sum(1).astype(float), axis=0)
#       4 female_show.plot(kind="bar", stacked=True, title="pclass survived rate in female")
#       5 plt.xlabel("pclass")
#
# C:\Users\zlm\Anaconda2\lib\site-packages\pandas\core\frame.pyc in __getitem__(self, key)
#    2060             return self._getitem_multilevel(key)
#    2061         else:
# -> 2062             return self._getitem_column(key)
#    2063
#    2064     def _getitem_column(self, key):
#
# C:\Users\zlm\Anaconda2\lib\site-packages\pandas\core\frame.pyc in _getitem_column(self, key)
#    2067         # get column
# ...

# %%
female_df = data_train[data_train["Sex"] == "female"]
female_ct = pd.crosstab(female_df["Pclass"], female_df["Survived"])
female_show = female_ct.div(female_ct.sum(1).astype(float), axis=0)
female_show.plot(kind="bar", stacked=True, title("pclass survived rate in female"))
plt.xlabel("pclass")
plt.ylabel("survived rate")
plt.show()
# Out:
#   File "<ipython-input-42-d1024cd3022a>", line 4
#     female_show.plot(kind="bar", stacked=True, title("pclass survived rate in female"))
# SyntaxError: non-keyword arg after keyword arg

# %%
female_df = data_train[data_train["Sex"] == "female"]
female_ct = pd.crosstab(female_df["Pclass"], female_df["Survived"])
female_show = female_ct.div(female_ct.sum(1).astype(float), axis=0)
female_show.plot(kind="bar", stacked=True, title=("pclass survived rate in female"))
plt.xlabel("pclass")
plt.ylabel("survived rate")
plt.show()

# %%
data_train[data_train["Embarked"].isnull()]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked  Sev_Val
# 61   female  38.0      0      0  113572  80.0   B28      NaN        0
# 829  female  62.0      0      0  113572  80.0   B28      NaN        0

# %%
embarked = sorted(data_train["Embarked"].unique())
embarked_map = dict(zip(embarked, range(0, len(embarked)+1)))
Embarked_Var = data_train["Embarked"].map(embarked_map).astype(int)
data_train["Embarked_Val"] = Embarked_Var
data_train.describe
# Out:
# <bound method DataFrame.describe of      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# ...

# %%
data_train.head
# Out:
# <bound method DataFrame.head of      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
data_train["Embarked_Val"].hist(bins=len(embarked), range(0, 3))
plt.xlabel("embarked")
plt.ylabel("count")
plt.show()
# Out:
#   File "<ipython-input-47-1fbcd937ac49>", line 1
#     data_train["Embarked_Val"].hist(bins=len(embarked), range(0, 3))
# SyntaxError: non-keyword arg after keyword arg

# %%
data_train["Embarked_Val"].hist(bins=len(embarked), range=(0, 3))
plt.xlabel("embarked")
plt.ylabel("count")
plt.show()

# %%
embarked_map
# Out:
# {nan: 0, 'C': 1, 'Q': 2, 'S': 3}

# %%
if len(data_train[data_train["Embarked"].isnull()]) > 0:
    data_train.replace({"Embarked_Val":{0:3}}, inplace=True)

# %%
embarked = sorted(data_train["Embarked_Val"].unique())
print embarked
# Out:
# [1, 2, 3]

# %%
embakred_ct = pd.crosstab(data_train["Embarked_Val"], data_train["Survived"])
embarked_plt = embarked_ct.div(embarked_ct.sum(1).astype(float))
ecbarked_ct
embarked_plt
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-b0fb69486d66> in <module>()
#       1 embakred_ct = pd.crosstab(data_train["Embarked_Val"], data_train["Survived"])
# ----> 2 embarked_plt = embarked_ct.div(embarked_ct.sum(1).astype(float))
#       3 ecbarked_ct
#       4 embarked_plt
#
# NameError: name 'embarked_ct' is not defined

# %%
embarked_ct = pd.crosstab(data_train["Embarked_Val"], data_train["Survived"])
embarked_plt = embarked_ct.div(embarked_ct.sum(1).astype(float))
ecbarked_ct
embarked_plt
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-55-5da6c22e99aa> in <module>()
#       1 embarked_ct = pd.crosstab(data_train["Embarked_Val"], data_train["Survived"])
#       2 embarked_plt = embarked_ct.div(embarked_ct.sum(1).astype(float))
# ----> 3 ecbarked_ct
#       4 embarked_plt
#
# NameError: name 'ecbarked_ct' is not defined

# %%
embarked_ct = pd.crosstab(data_train["Embarked_Val"], data_train["Survived"])
embarked_plt = embarked_ct.div(embarked_ct.sum(1).astype(float))
embarked_ct
embarked_plt
# Out:
#                0         1   2   3
# Embarked_Val
# 1            NaN  0.553571 NaN NaN
# 2            NaN  0.178571 NaN NaN
# 3            NaN  1.303571 NaN NaN

# %%
embarked_ct
# Out:
# Survived        0    1
# Embarked_Val
# 1              75   93
# 2              47   30
# 3             427  219

# %%
embarked_plt = embarked_ct.div(embarked_ct.sum(1).astype(float), axis=0)
print type(embarked_ct)
print embarked_plt
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Survived             0         1
# Embarked_Val
# 1             0.446429  0.553571
# 2             0.610390  0.389610
# 3             0.660991  0.339009

# %%
embarked_plt.plot(kind="bar", stacked=True, title="survived rate by embarked")
plt.xlabel("embarked")
plt.ylabel("survived_rate")

# %%
plt.show()

# %%
fig = plt.figure(figsize=fizsize_with_subplots) 

rows = 2
cols = 3
col_names = ('Sev_Val', 'Pclass')
for port in embarked:
    for col_index in range(0, len(col_names)):
        plt.subplot2grid((rows, cols), (col_index, port - 1))
        data_train[data_train["Embarked_Val"]==port][col_names[col_index]].value_counts.plot(kind="bar")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-61-1a2921c9b584> in <module>()
#       7     for col_index in range(0, len(col_names)):
#       8         plt.subplot2grid((rows, cols), (col_index, port - 1))
# ----> 9         data_train[data_train["Embarked_Val"]==port][col_names[col_index]].value_counts.plot(kind="bar")
#      10
#
# AttributeError: 'function' object has no attribute 'plot'

# %%
for port in embarked:
    for col_index in range(0, len(col_names)):
        plt.subplot2grid((rows, cols), (col_index, port - 1))
        data_train[data_train["Embarked_Val"]==port][col_names[col_index]].value_counts().plot(kind="bar")

# %%
plt.show()

# %%
data_train = pd.concat([data_train, pd.get_dummies(data_train['Embarked_Val'], prefix='Embarked_Val')], axis=1)

# %%
data_train["Age"].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5       True
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17      True
# 18     False
# 19      True
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26      True
# 27     False
# 28      True
# 29      True
#        ...
# 861    False
# 862    False
# 863     True
# 864    False
# 865    False
# 866    False
# 867    False
# 868     True
# 869    False
# 870    False
# 871    False
# 872    False
# 873    False
# 874    False
# 875    False
# 876    False
# 877    False
# 878     True
# 879    False
# 880    False
# 881    False
# 882    False
# 883    False
# 884    False
# 885    False
# 886    False
# 887    False
# 888     True
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
data_train[data_train["Age"].isnull()]
# Out:
#      PassengerId  Survived  Pclass  \
# 5              6         0       3
# 17            18         1       2
# 19            20         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 31            32         1       1
# 32            33         1       3
# 36            37         1       3
# 42            43         0       3
# 45            46         0       3
# 46            47         0       3
# 47            48         1       3
# 48            49         0       3
# 55            56         1       1
# 64            65         0       1
# 65            66         1       3
# 76            77         0       3
# 77            78         0       3
# 82            83         1       3
# 87            88         0       3
# 95            96         0       3
# 101          102         0       3
# 107          108         1       3
# 109          110         1       3
# ...

# %%
data_train[data_train["Age"].isnull()][["Age","Sex","Pclass"]].describe
# Out:
# <bound method DataFrame.describe of      Age     Sex  Pclass
# 5    NaN    male       3
# 17   NaN    male       2
# 19   NaN  female       3
# 26   NaN    male       3
# 28   NaN  female       3
# 29   NaN    male       3
# 31   NaN  female       1
# 32   NaN  female       3
# 36   NaN    male       3
# 42   NaN    male       3
# 45   NaN    male       3
# 46   NaN    male       3
# 47   NaN  female       3
# 48   NaN    male       3
# 55   NaN    male       1
# 64   NaN    male       1
# 65   NaN    male       3
# 76   NaN    male       3
# 77   NaN    male       3
# 82   NaN  female       3
# 87   NaN    male       3
# 95   NaN    male       3
# 101  NaN    male       3
# 107  NaN    male       3
# 109  NaN  female       3
# 121  NaN    male       3
# 126  NaN    male       3
# 128  NaN  female       3
# 140  NaN  female       3
# 154  NaN    male       3
# ..   ...     ...     ...
# 718  NaN    male       3
# 727  NaN  female       3
# 732  NaN    male       2
# ...

# %%
data_train[data_train["Age"].isnull()][["Age","Sex","Pclass"]].head
# Out:
# <bound method DataFrame.head of      Age     Sex  Pclass
# 5    NaN    male       3
# 17   NaN    male       2
# 19   NaN  female       3
# 26   NaN    male       3
# 28   NaN  female       3
# 29   NaN    male       3
# 31   NaN  female       1
# 32   NaN  female       3
# 36   NaN    male       3
# 42   NaN    male       3
# 45   NaN    male       3
# 46   NaN    male       3
# 47   NaN  female       3
# 48   NaN    male       3
# 55   NaN    male       1
# 64   NaN    male       1
# 65   NaN    male       3
# 76   NaN    male       3
# 77   NaN    male       3
# 82   NaN  female       3
# 87   NaN    male       3
# 95   NaN    male       3
# 101  NaN    male       3
# 107  NaN    male       3
# 109  NaN  female       3
# 121  NaN    male       3
# 126  NaN    male       3
# 128  NaN  female       3
# 140  NaN  female       3
# 154  NaN    male       3
# ..   ...     ...     ...
# 718  NaN    male       3
# 727  NaN  female       3
# 732  NaN    male       2
# ...

# %%
data_train[data_train["Age"].isnull()][["Age","Sex","Pclass"]].head()
# Out:
#     Age     Sex  Pclass
# 5   NaN    male       3
# 17  NaN    male       2
# 19  NaN  female       3
# 26  NaN    male       3
# 28  NaN  female       3

# %%
data_train["AgeFill"] = data_train["Age"]
print data_train["AgeFill"].groupby([data_train["Sex"], data_train["Pclass"]])

# %%
data_train["AgeFill"]=data_train["AgeFill"].groupby([data_train["Sex"], data_train["Pclass"]]).apply(lambda x:x.fillna(x.median()))

# %%
print len(data_train[data_train["AgeFill"].isnull()])
# Out:
# 0

# %%
print fizsize_with_subplots
# Out:
# (10, 10)

# %%
fig, axis = plt.subplots(2, 1, figsize=fizsize_with_subplots)
df1 = data_train[data_train["survived"]==0]["Age"]
df2 = data_train[data_train["survived"]==1]["Age"]
max_age = max(data_train["AgeFill"])

axis[0].hist([df1, df2], bins=max_age/bin_size, range=(0, max_age), stacked=True)
axis[0].legend(("Died", "Survived"),loc="best")
axis[0].set_title("survivors by age groups histogram")
axis[0].set_xlabel("age")
axis[0].set_ylabel("survivor")

axis[1].scatter(data_train["Survived"], data_train["Age"])
axis[1].set_title("Survivors by Age Plot")
axis[1].set_xlabel("survived")
axis[1].set_ylabel("age")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-74-918f621d2fd7> in <module>()
#       1 fig, axis = plt.subplots(2, 1, figsize=fizsize_with_subplots)
# ----> 2 df1 = data_train[data_train["survived"]==0]["Age"]
#       3 df2 = data_train[data_train["survived"]==1]["Age"]
#       4 max_age = max(data_train["AgeFill"])
#       5
#
# C:\Users\zlm\Anaconda2\lib\site-packages\pandas\core\frame.pyc in __getitem__(self, key)
#    2060             return self._getitem_multilevel(key)
#    2061         else:
# -> 2062             return self._getitem_column(key)
#    2063
#    2064     def _getitem_column(self, key):
#
# C:\Users\zlm\Anaconda2\lib\site-packages\pandas\core\frame.pyc in _getitem_column(self, key)
#    2067         # get column
#    2068         if self.columns.is_unique:
# -> 2069             return self._get_item_cache(key)
#    2070
# ...

# %%
fig, axis = plt.subplots(2, 1, figsize=fizsize_with_subplots)
df1 = data_train[data_train["Survived"]==0]["Age"]
df2 = data_train[data_train["Survived"]==1]["Age"]
max_age = max(data_train["AgeFill"])

axis[0].hist([df1, df2], bins=max_age/bin_size, range=(0, max_age), stacked=True)
axis[0].legend(("Died", "Survived"),loc="best")
axis[0].set_title("survivors by age groups histogram")
axis[0].set_xlabel("age")
axis[0].set_ylabel("survivor")

axis[1].scatter(data_train["Survived"], data_train["Age"])
axis[1].set_title("Survivors by Age Plot")
axis[1].set_xlabel("survived")
axis[1].set_ylabel("age")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-75-de5b5a76a7e5> in <module>()
#       4 max_age = max(data_train["AgeFill"])
#       5
# ----> 6 axis[0].hist([df1, df2], bins=max_age/bin_size, range=(0, max_age), stacked=True)
#       7 axis[0].legend(("Died", "Survived"),loc="best")
#       8 axis[0].set_title("survivors by age groups histogram")
#
# C:\Users\zlm\Anaconda2\lib\site-packages\matplotlib\__init__.pyc in inner(ax, *args, **kwargs)
#    1895                     warnings.warn(msg % (label_namer, func.__name__),
#    1896                                   RuntimeWarning, stacklevel=2)
# -> 1897             return func(ax, *args, **kwargs)
#    1898         pre_doc = inner.__doc__
#    1899         if pre_doc is None:
#
# C:\Users\zlm\Anaconda2\lib\site-packages\matplotlib\axes\_axes.pyc in hist(***failed resolving arguments***)
# ...

# %%
fig, axis = plt.subplots(2, 1, figsize=fizsize_with_subplots)
df1 = data_train[data_train["Survived"]==0]["Age"]
df2 = data_train[data_train["Survived"]==1]["Age"]
max_age = max(data_train["AgeFill"])

axis[0].hist([df1, df2], bins=int(max_age/bin_size), range=(1, max_age), stacked=True)
axis[0].legend(("Died", "Survived"),loc="best")
axis[0].set_title("survivors by age groups histogram")
axis[0].set_xlabel("age")
axis[0].set_ylabel("survivor")

axis[1].scatter(data_train["Survived"], data_train["Age"])
axis[1].set_title("Survivors by Age Plot")
axis[1].set_xlabel("survived")
axis[1].set_ylabel("age")
plt.show()
# Out:
# C:\Users\zlm\Anaconda2\lib\site-packages\numpy\lib\function_base.py:747: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= mn)
# C:\Users\zlm\Anaconda2\lib\site-packages\numpy\lib\function_base.py:748: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= mx)

# %%
pclasses = sorted(data_train["Pclass"].unique())
for pc in pclasses:
    data_train.AgeFill[data_train.Pclass==pc].plot(kind="kde")

plt.title("age density plot by pclass")
plt.xlabel("age")
plt.legend(("1st class", "2nd class", "3th class"), loc="best")
plt.show()

# %%
# Set up a grid of plots
fig = plt.figure(figsize=fizsize_with_subplots) 
fig_dims = (3, 1)

plt.subplot2grid(fig_dims, (0,0))
sur_df = data_train[data_train["Survived"]==1]
sur_df["AgeFill"].hist(bins=int(max_age/bin_size), range=(1, max_age))

plt.subplot2grid(fig_dims, (1,0))
female_sur = data_train[data_train["Survived"]==1 & data_train["Sev_val"]==0]
female_sur["AgeFill"].hist(bins=int(max_age/bin_size), range=(1, max_age))

plt.subplot2grid(fig_dims, (2,0))
pclass_sur = data_train[data_train["Pclass"]==1 & data_train["Survived"]==1]
pclass_sur["AgeFill"].hist(bins=int(max_age/bin_size), range=(1, max_age))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-78-fbb1cede1adb> in <module>()
#       8
#       9 plt.subplot2grid(fig_dims, (1,0))
# ---> 10 female_sur = data_train[data_train["Survived"]==1 & data_train["Sev_val"]==0]
#      11 female_sur["AgeFill"].hist(bins=int(max_age/bin_size), range=(1, max_age))
#      12
#
# C:\Users\zlm\Anaconda2\lib\site-packages\pandas\core\frame.pyc in __getitem__(self, key)
#    2060             return self._getitem_multilevel(key)
#    2061         else:
# -> 2062             return self._getitem_column(key)
#    2063
#    2064     def _getitem_column(self, key):
#
# C:\Users\zlm\Anaconda2\lib\site-packages\pandas\core\frame.pyc in _getitem_column(self, key)
#    2067         # get column
#    2068         if self.columns.is_unique:
# -> 2069             return self._get_item_cache(key)
#    2070
# ...

# %%
# Set up a grid of plots
fig = plt.figure(figsize=fizsize_with_subplots) 
fig_dims = (3, 1)

plt.subplot2grid(fig_dims, (0,0))
sur_df = data_train[data_train["Survived"]==1]
sur_df["AgeFill"].hist(bins=int(max_age/bin_size), range=(1, max_age))

plt.subplot2grid(fig_dims, (1,0))
female_sur = data_train[data_train["Survived"]==1 & data_train["Sev_Val"]==0]
female_sur["AgeFill"].hist(bins=int(max_age/bin_size), range=(1, max_age))

plt.subplot2grid(fig_dims, (2,0))
pclass_sur = data_train[data_train["Pclass"]==1 & data_train["Survived"]==1]
pclass_sur["AgeFill"].hist(bins=int(max_age/bin_size), range=(1, max_age))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-79-6f45e421383c> in <module>()
#       8
#       9 plt.subplot2grid(fig_dims, (1,0))
# ---> 10 female_sur = data_train[data_train["Survived"]==1 & data_train["Sev_Val"]==0]
#      11 female_sur["AgeFill"].hist(bins=int(max_age/bin_size), range=(1, max_age))
#      12
#
# C:\Users\zlm\Anaconda2\lib\site-packages\pandas\core\generic.pyc in __nonzero__(self)
#     951         raise ValueError("The truth value of a {0} is ambiguous. "
#     952                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# --> 953                          .format(self.__class__.__name__))
#     954
#     955     __bool__ = __nonzero__
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
# Set up a grid of plots
fig = plt.figure(figsize=fizsize_with_subplots) 
fig_dims = (3, 1)

plt.subplot2grid(fig_dims, (0,0))
sur_df = data_train[data_train["Survived"]==1]
sur_df["AgeFill"].hist(bins=int(max_age/bin_size), range=(1, max_age))

plt.subplot2grid(fig_dims, (1,0))
female_sur = data_train[(data_train["Survived"]==1 and data_train["Sev_Val"]==0)]
female_sur["AgeFill"].hist(bins=int(max_age/bin_size), range=(1, max_age))

plt.subplot2grid(fig_dims, (2,0))
pclass_sur = data_train[(data_train["Pclass"]==1 and data_train["Survived"]==1)]
pclass_sur["AgeFill"].hist(bins=int(max_age/bin_size), range=(1, max_age))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-80-9aa3e0a09ca6> in <module>()
#       8
#       9 plt.subplot2grid(fig_dims, (1,0))
# ---> 10 female_sur = data_train[(data_train["Survived"]==1 and data_train["Sev_Val"]==0)]
#      11 female_sur["AgeFill"].hist(bins=int(max_age/bin_size), range=(1, max_age))
#      12
#
# C:\Users\zlm\Anaconda2\lib\site-packages\pandas\core\generic.pyc in __nonzero__(self)
#     951         raise ValueError("The truth value of a {0} is ambiguous. "
#     952                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# --> 953                          .format(self.__class__.__name__))
#     954
#     955     __bool__ = __nonzero__
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
# Set up a grid of plots
fig = plt.figure(figsize=fizsize_with_subplots) 
fig_dims = (3, 1)

plt.subplot2grid(fig_dims, (0,0))
sur_df = data_train[data_train["Survived"]==1]
sur_df["AgeFill"].hist(bins=int(max_age/bin_size), range=(1, max_age))

plt.subplot2grid(fig_dims, (1,0))
female_sur = data_train[(data_train["Survived"]==1) & (data_train["Sev_Val"]==0)]
female_sur["AgeFill"].hist(bins=int(max_age/bin_size), range=(1, max_age))

plt.subplot2grid(fig_dims, (2,0))
pclass_sur = data_train[(data_train["Pclass"]==1) & (data_train["Survived"]==1)]
pclass_sur["AgeFill"].hist(bins=int(max_age/bin_size), range=(1, max_age))
plt.show()

# %%
data_train["FamilySize"] = data_train["SibSp"] + data_train["Parch"]
data_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Sev_Val  Embarked_Val  \
# 0      0         A/5 21171   7.2500   NaN        S        1             3
# 1      0          PC 17599  71.2833   C85        C        0             1
# 2      0  STON/O2. 3101282   7.9250   NaN        S        0             3
# ...

# %%
data_train["FamilySize"].hist()
plt.title("Family size histogram")
plt.show()

# %%
df1 = data_train[data_train["Survived"]==1]["FamilySize"]
df2 = data_train[data_train["Survived"]==0]["FamilySize"]
family_sizes = data_train["FamilySize"].unique()
max_family_size = max(family_sizes)
plt.hist([df1, df2], bins = max_family_size+1, range=(0, max_family_size+1),stacked=True)
plt.legend(("survived", "died"),loc="best")
plt.title("survivors by family size")
plt.show()

# %%
data_train.dtypes[data_train.dtypes.amp(lambda x: x == 'object')]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-85-015fade0bddf> in <module>()
# ----> 1 data_train.dtypes[data_train.dtypes.amp(lambda x: x == 'object')]
#
# C:\Users\zlm\Anaconda2\lib\site-packages\pandas\core\generic.pyc in __getattr__(self, name)
#    2968             if name in self._info_axis:
#    2969                 return self[name]
# -> 2970             return object.__getattribute__(self, name)
#    2971
#    2972     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'amp'

# %%
data_train.dtypes[data_train.dtypes.map(lambda x: x == 'object')]
# Out:
# Name        object
# Sex         object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %%
data_train = data_train.drop(["Name", "Sex", "Ticket","Cabin", "Embarked"], axis=1)

# %%
data_train = data_train.drop(['Age','SibSp','Parch','PassengerId','Embarked_Val'], axis=1)

# %%
data_train.dtypes
# Out:
# Survived            int64
# Pclass              int64
# Fare              float64
# Sev_Val             int32
# Embarked_Val_1      uint8
# Embarked_Val_2      uint8
# Embarked_Val_3      uint8
# AgeFill           float64
# FamilySize          int64
# dtype: object

# %%
train_data = data_train.values
train_data
# Out:
# array([[  0.    ,   3.    ,   7.25  , ...,   1.    ,  22.    ,   1.    ],
#        [  1.    ,   1.    ,  71.2833, ...,   0.    ,  38.    ,   1.    ],
#        [  1.    ,   3.    ,   7.925 , ...,   1.    ,  26.    ,   0.    ],
#        ...,
#        [  0.    ,   3.    ,  23.45  , ...,   1.    ,  21.5   ,   3.    ],
#        [  1.    ,   1.    ,  30.    , ...,   0.    ,  26.    ,   0.    ],
#        [  0.    ,   3.    ,   7.75  , ...,   0.    ,  32.    ,   0.    ]])

# %%
def clean_data(df, drop_passenger_id):
    sexes = sorted(df["Sex"].unique())
    sex_map = dict(zip(sexes, range(0, len(sexes)+1)))
    df["Sex_Val"] = df["Sex"].map(sex_map).astype(int)
    
    # Get the unique values of Embarked
    embarked_locs = sorted(df['Embarked'].unique())

    # Generate a mapping of Embarked from a string to a number representation        
    embarked_locs_mapping = dict(zip(embarked_locs, 
                                     range(0, len(embarked_locs) + 1)))
    
    # Transform Embarked from a string to dummy variables
    df = pd.concat([df, pd.get_dummies(df['Embarked'], prefix='Embarked_Val')], axis=1)
    
    # Fill in missing values of Embarked
    # Since the vast majority of passengers embarked in 'S': 3, 
    # we assign the missing values in Embarked to 'S':
    if len(df[df['Embarked'].isnull()] > 0):
        df.replace({'Embarked_Val' : 
                       { embarked_locs_mapping[nan] : embarked_locs_mapping['S'] 
                       }
                   }, 
                   inplace=True)
    
    # Fill in missing values of Fare with the average Fare
    if len(df[df['Fare'].isnull()] > 0):
        avg_fare = df['Fare'].mean()
        df.replace({ None: avg_fare }, inplace=True)
    
    # To keep Age in tact, make a copy of it called AgeFill 
    # that we will use to fill in the missing ages:
    df['AgeFill'] = df['Age']

    # Determine the Age typical for each passenger class by Sex_Val.  
    # We'll use the median instead of the mean because the Age 
    # histogram seems to be right skewed.
    df['AgeFill'] = df['AgeFill'] \
                        .groupby([df['Sex_Val'], df['Pclass']]) \
                        .apply(lambda x: x.fillna(x.median()))
            
    # Define a new feature FamilySize that is the sum of 
    # Parch (number of parents or children on board) and 
    # SibSp (number of siblings or spouses):
    df['FamilySize'] = df['SibSp'] + df['Parch']
    
    # Drop the columns we won't use:
    df = df.drop(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], axis=1)
    
    # Drop the Age column since we will be using the AgeFill column instead.
    # Drop the SibSp and Parch columns since we will be using FamilySize.
    # Drop the PassengerId column since it won't be used as a feature.
    df = df.drop(['Age', 'SibSp', 'Parch'], axis=1)
    
    if drop_passenger_id:
        df = df.drop(['PassengerId'], axis=1)
    
    return df

# %%
from sklearn.ensemble import RandomForestClassifier

clf = RandomForestClassifier(n_estimators=100)

# %%
# Training data features, skip the first column 'Survived'
train_features = train_data[:, 1:]

# 'Survived' column values
train_target = train_data[:, 0]

clf = clf.fit(train_features, train_target)
score = clf.score(train_features, train_target)

"Mean accuracy of Random Forest:{0}".format(score)
# Out:
# 'Mean accuracy of Random Forest:0.980920314254'

# %%
df_test = pd.read_csv("test.csv")
df_test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
df_test = clean_data(df_test, drop_passenger_id=False)

# %%
test_data = df_test.values

# %%
test_x = test_data[:,1:]
test_y = clf.predict(test_x)

# %%
df_test['Survived'] = test_y
df_test["PassengerId","Survived"].to_csv('result.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-100-214518c15461> in <module>()
#       1 df_test['Survived'] = test_y
# ----> 2 df_test["PassengerId","Survived"].to_csv('result.csv', index=False)
#
# C:\Users\zlm\Anaconda2\lib\site-packages\pandas\core\frame.pyc in __getitem__(self, key)
#    2060             return self._getitem_multilevel(key)
#    2061         else:
# -> 2062             return self._getitem_column(key)
#    2063
#    2064     def _getitem_column(self, key):
#
# C:\Users\zlm\Anaconda2\lib\site-packages\pandas\core\frame.pyc in _getitem_column(self, key)
#    2067         # get column
#    2068         if self.columns.is_unique:
# -> 2069             return self._get_item_cache(key)
#    2070
#    2071         # duplicate columns & possible reduce dimensionality
#
# ...

# %%
df_test[["PassengerId","Survived"]].to_csv('result.csv', index=False)

# %%
from sklearn import metrics
from sklearn.cross_validation import train_test_split
train_x, test_x, train_y, test_y = train_test_split(train_features, train_target, test_size=0.2, random_state=0)
print type(train_features)
print train_features.shape, train_target.shape
print train_x.shape, train_y.shape
print test_x.shap, test_y.shape
# Out:
# C:\Users\zlm\Anaconda2\lib\site-packages\sklearn\cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# <type 'numpy.ndarray'>
# (891L, 8L) (891L,)
# (712L, 8L) (712L,)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-102-71d3f7944078> in <module>()
#       5 print train_features.shape, train_target.shape
#       6 print train_x.shape, train_y.shape
# ----> 7 print test_x.shap, test_y.shape
#
# AttributeError: 'numpy.ndarray' object has no attribute 'shap'

# %%
print test_x.shape, test_y.shape
# Out:
# (179L, 8L) (179L,)

# %%
clf = clf.fit(train_x, train_y)
predict_y = clf.predict(test_x)

# %%
from sklearn.metrics import accuracy_score
print "accuracy=%.2f" % accuracy_score(test_y, predcit_y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-105-3d30c1300e5a> in <module>()
#       1 from sklearn.metrics import accuracy_score
# ----> 2 print "accuracy=%.2f" % accuracy_score(test_y, predcit_y)
#
# NameError: name 'predcit_y' is not defined

# %%
print "accuracy=%.2f" % accuracy_score(test_y, predict_y)
# Out:
# accuracy=0.84
